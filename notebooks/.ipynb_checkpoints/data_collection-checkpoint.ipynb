# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
from datetime import date

# %% [markdown]
# ## Download a single stock data

# %%
ticker = "aapl"
today = date.today().strftime("%Y-%m-%d")
stock_data = yf.download(ticker, start="2020-1-1", end=today)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(stock_data)
# Out:
# pandas.core.frame.DataFrame

# %%
stock_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-12-31  72.482498  73.419998  72.379997  73.412498  72.337982  100805600
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.988480  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  73.269157  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.852982  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  73.505646  108872000

# %%
# convert to numpy arrays
open_arr = stock_data['Open'].to_numpy()
high_arr = stock_data['High'].to_numpy()
low_arr = stock_data['Low'].to_numpy()
close_arr = stock_data['Close'].to_numpy()

# %%
open_ = stock_data['Open']
high_ = stock_data['High']
low_ = stock_data['Low']
close_ = stock_data['Close']

# %%
fig = plt.figure(figsize=(16, 5))
ax = plt.subplot()
ax.set_title(ticker)
ax.plot(open_, label='Open')
ax.plot(high_, label='High')
ax.plot(low_, label='Low')
ax.plot(close_, label='Close')
ax.legend()
ax.set_xlabel('Date')
ax.set_ylabel('Value USD')
ax.grid()

# %% [markdown]
# ## Get a banch of Stocks data

# %%
stocks = ['AAPL', 'SPY', 'GOOG']
tickers = ' '.join(stocks)
start_date = date(2018, 1, 1).strftime("%Y-%m-%d")
end_date = date(2020, 1, 1).strftime("%Y-%m-%d")
stocks_data = yf.download(tickers, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks_data.head()
# Out:
#             Adj Close                               Close               \
#                  AAPL         GOOG         SPY       AAPL         GOOG
# Date
# 2018-01-02  41.188156  1065.000000  251.651001  43.064999  1065.000000
# 2018-01-03  41.180988  1082.479980  253.242783  43.057499  1082.479980
# 2018-01-04  41.372272  1086.400024  254.310104  43.257500  1086.400024
# 2018-01-05  41.843311  1102.229980  256.004852  43.750000  1102.229980
# 2018-01-08  41.687889  1106.939941  256.472961  43.587502  1106.939941
#
#                              High                                 Low  \
#                    SPY       AAPL         GOOG         SPY       AAPL
# Date
# 2018-01-02  268.769989  43.075001  1066.939941  268.809998  42.314999
# 2018-01-03  270.470001  43.637501  1086.290039  270.640015  42.990002
# 2018-01-04  271.609985  43.367500  1093.569946  272.160004  43.020000
# 2018-01-05  273.420013  43.842499  1104.250000  273.559998  43.262501
# 2018-01-08  273.920013  43.902500  1111.270020  274.100006  43.482498
#
#                                           Open                           \
#                    GOOG         SPY       AAPL         GOOG         SPY
# Date
# 2018-01-02  1045.229980  267.399994  42.540001  1048.339966  267.839996
# 2018-01-03  1063.209961  268.959991  43.132500  1064.310059  268.959991
# 2018-01-04  1084.001953  270.540009  43.134998  1088.000000  271.200012
# 2018-01-05  1092.000000  271.950012  43.360001  1094.000000  272.510010
# 2018-01-08  1101.619995  272.980011  43.587502  1102.229980  273.309998
#
#                Volume
#                  AAPL     GOOG       SPY
# Date
# 2018-01-02  102223600  1237600  86655700
# 2018-01-03  118071600  1430200  90070400
# 2018-01-04   89738400  1004600  80636400
# 2018-01-05   94640000  1279100  83524000
# 2018-01-08   82271200  1047600  57319200

# %%
stocks_data['Close']
# Out:
#                  AAPL         GOOG         SPY
# Date
# 2018-01-02  43.064999  1065.000000  268.769989
# 2018-01-03  43.057499  1082.479980  270.470001
# 2018-01-04  43.257500  1086.400024  271.609985
# 2018-01-05  43.750000  1102.229980  273.420013
# 2018-01-08  43.587502  1106.939941  273.920013
# ...               ...          ...         ...
# 2019-12-24  71.067497  1343.560059  321.230011
# 2019-12-26  72.477501  1360.400024  322.940002
# 2019-12-27  72.449997  1351.890015  322.859985
# 2019-12-30  72.879997  1336.140015  321.079987
# 2019-12-31  73.412498  1337.020020  321.859985
#
# [503 rows x 3 columns]

# %%
stocks_data['Close']['AAPL']
# Out:
# Date
# 2018-01-02    43.064999
# 2018-01-03    43.057499
# 2018-01-04    43.257500
# 2018-01-05    43.750000
# 2018-01-08    43.587502
#                 ...
# 2019-12-24    71.067497
# 2019-12-26    72.477501
# 2019-12-27    72.449997
# 2019-12-30    72.879997
# 2019-12-31    73.412498
# Name: AAPL, Length: 503, dtype: float64

# %%
fig = plt.figure(figsize=(16, 5))
ax = plt.subplot()
ax.set_title('Normalized Close')
for stock in stocks:
    ax.plot(stocks_data['Close'][stock] / stocks_data['Close'][stock].min(), label=stock)
ax.legend()
ax.set_xlabel('Date')
ax.set_ylabel('Value USD')
ax.grid()
